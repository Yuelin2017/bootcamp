# %%
import pandas as pd

# %%
# !head data/gfmt_sleep.csv
# Out:
# ﻿participant number,gender,age,correct hit percentage,correct reject percentage,percent correct,confidence when correct hit,confidence incorrect hit,confidence correct reject,confidence incorrect reject,confidence when correct,confidence when incorrect,sci,psqi,ess
# 8,f,39,65,80,72.5,91,90,93,83.5,93,90,9,13,2
# 16,m,42,90,90,90,75.5,55.5,70.5,50,75,50,4,11,7
# 18,f,31,90,95,92.5,89.5,90,86,81,89,88,10,9,3
# 22,f,35,100,75,87.5,89.5,*,71,80,88,80,13,8,20
# 27,f,74,60,65,62.5,68.5,49,61,49,65,49,13,9,12
# 28,f,61,80,20,50,71,63,31,72.5,64.5,70.5,15,14,2
# 30,m,32,90,75,82.5,67,56.5,66,65,66,64,16,9,3
# 33,m,62,45,90,67.5,54,37,65,81.5,62,61,14,9,9
# 34,f,33,80,100,90,70.5,76.5,64.5,*,68,76.5,14,12,10

# %%
pd.read_csv?
# Out:
# Signature: pd.read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# Docstring:
# Read CSV (comma-separated) file into DataFrame
#
# Also supports optionally iterating or breaking of the file
# ...

# %%
df=pd.read_csv('data/gfmt_sleep.csv',na_values='*')  #dataframe is a struvture, like a string, has its method
# still have the original file intact
# how to save df then?

# %%
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence incorrect hit  confidence correct reject  \
# 0                      90.0                       93.0
# ...

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-ad11118bc8f3> in <module>()
# ----> 1 df[0]
#
# ...

# %%
# colomn index: usually string, row index: anything immutable
df['percent correct'].head()

# %%
df['percent correct'][3]   # not often used

# %%
df.loc[3,'percent correct']
# Out:
# 87.5

# %%
df.loc[3]
# Out:
# participant number               22
# gender                            f
# age                              35
# correct hit percentage          100
# correct reject percentage        75
# percent correct                87.5
# confidence when correct hit    89.5
# confidence incorrect hit        NaN
# confidence correct reject        71
# confidence incorrect reject      80
# confidence when correct          88
# confidence when incorrect        80
# sci                              13
# psqi                              8
# ess                              20
# Name: 3, dtype: object

# %%
# boolian indexing
df.loc[df['participant number']==22,'percent correct']
# Out:
# 3    87.5
# Name: percent correct, dtype: float64

# %%
# df.loc[(df['gender']=='f') | (df['age']<21),:]
df_female_minor=df.loc[(df['gender']=='f') & (df['age']<21),:]
df_female_minor
# Out:
#     participant number gender  age  correct hit percentage  \
# 27                   3      f   16                      70
# 29                   5      f   18                      90
# 66                  58      f   16                      85
# 79                  72      f   18                      80
# 88                  85      f   18                      85
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 27                         80             75.0                         70.0
# 29                        100             95.0                         76.5
# 66                         85             85.0                         55.0
# 79                         75             77.5                         67.5
# 88                         85             85.0                         93.0
#
#     confidence incorrect hit  confidence correct reject  \
# 27                      57.0                       54.0
# ...

# %%
inds = (df['gender']=='f') & (df['age']>30) & (df['percent correct']>85)
df.loc[inds,:]
inds.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
# make a new coloumn out of a boolian
df['insomnia'] = df['sci'] <= 16

# %%
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence incorrect hit  confidence correct reject  \
# 0                      90.0                       93.0
# ...

# %%
df.dtypes   # object means mixed types
# Out:
# participant number               int64
# gender                          object
# age                              int64
# correct hit percentage           int64
# correct reject percentage        int64
# percent correct                float64
# confidence when correct hit    float64
# confidence incorrect hit       float64
# confidence correct reject      float64
# confidence incorrect reject    float64
# confidence when correct        float64
# confidence when incorrect      float64
# sci                              int64
# psqi                             int64
# ess                              int64
# insomnia                          bool
# dtype: object

# %%
df['insomnia'].astype(float)
df['insomnia']=['insomnia'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-8efef7e2eaf0> in <module>()
#       1 df['insomnia'].astype(float)
# ----> 2 df['insomnia']=['insomnia'].astype(float)
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
df.loc[25,'insomnia']='can change to another type'

# %%
df.describe()
# Out:
#        participant number         age  correct hit percentage  \
# count          102.000000  102.000000              102.000000
# mean            52.049020   37.921569               83.088235
# std             30.020909   14.029450               15.091210
# min              1.000000   16.000000               35.000000
# 25%             26.250000   26.500000               75.000000
# 50%             52.500000   36.500000               90.000000
# 75%             77.750000   45.000000               95.000000
# max            103.000000   74.000000              100.000000
#
#        correct reject percentage  percent correct  \
# count                 102.000000       102.000000
# mean                   77.205882        80.147059
# std                    17.569854        12.047881
# min                    20.000000        40.000000
# 25%                    70.000000        72.500000
# 50%                    80.000000        83.750000
# 75%                    90.000000        87.500000
# ...

# %%
df.loc[df['insomnia']==True,:].describe()
# Out:
#        participant number        age  correct hit percentage  \
# count           25.000000  25.000000               25.000000
# mean            53.400000  40.320000               82.000000
# std             29.219001  12.915495               18.314384
# min              8.000000  24.000000               40.000000
# 25%             30.000000  31.000000               70.000000
# 50%             46.000000  39.000000               90.000000
# 75%             78.000000  44.000000              100.000000
# max            101.000000  74.000000              100.000000
#
#        correct reject percentage  percent correct  \
# count                   25.00000        25.000000
# mean                    70.20000        76.100000
# std                     23.33988        13.347909
# min                     20.00000        45.000000
# 25%                     55.00000        70.000000
# 50%                     75.00000        75.000000
# 75%                     90.00000        87.500000
# ...

# %%
grouped = df.groupby('insomnia')

# %%
grouped.median()
# Out:
#                             participant number   age  correct hit percentage  \
# insomnia
# False                                     55.0  36.0                    90.0
# True                                      46.0  39.0                    90.0
# can change to another type                 1.0  42.0                    80.0
#
#                             correct reject percentage  percent correct  \
# insomnia
# False                                            80.0             85.0
# True                                             75.0             75.0
# can change to another type                       65.0             72.5
#
#                             confidence when correct hit  \
# insomnia
# False                                             74.75
# True                                              76.50
# can change to another type                        51.50
#
#                             confidence incorrect hit  \
# insomnia
# ...

# %%
grouped['percent correct'].median()
# Out:
# insomnia
# False                         85.0
# True                          75.0
# can change to another type    72.5
# Name: percent correct, dtype: float64

# %%
grouped.median()['percent correct']
# Out:
# insomnia
# False                         85.0
# True                          75.0
# can change to another type    72.5
# Name: percent correct, dtype: float64

# %%
grouped.median().reset_index()
# Out:
#                      insomnia  participant number   age  \
# 0                       False                55.0  36.0
# 1                        True                46.0  39.0
# 2  can change to another type                 1.0  42.0
#
#    correct hit percentage  correct reject percentage  percent correct  \
# 0                    90.0                       80.0             85.0
# 1                    90.0                       75.0             75.0
# 2                    80.0                       65.0             72.5
#
#    confidence when correct hit  confidence incorrect hit  \
# 0                        74.75                      55.5
# 1                        76.50                      72.0
# 2                        51.50                      44.5
#
#    confidence correct reject  confidence incorrect reject  \
# 0                      71.75                         59.5
# 1                      71.00                         68.5
# ...

# %%
grouped = df.groupby(['gender','insomnia'])

# %%
import numpy as np

# %%
def coeff_of_var(data):
    return np.std(data) / np.mean(data)

# %%
grouped.agg(coeff_of_var).reset_index()
# Out:
#   gender                    insomnia  participant number       age  \
# 0      f                       False            0.550674  0.393467
# 1      f                        True            0.537902  0.321095
# 2      f  can change to another type            0.000000  0.000000
# 3      m                       False            0.621005  0.370771
# 4      m                        True            0.530076  0.289036
#
#    correct hit percentage  correct reject percentage  percent correct  \
# 0                0.147990                   0.183995         0.130931
# 1                0.212433                   0.357680         0.179336
# 2                0.000000                   0.000000         0.000000
# 3                0.208510                   0.182287         0.155966
# 4                0.223150                   0.197311         0.117313
#
#    confidence when correct hit  confidence incorrect hit  \
# 0                     0.178959                  0.344596
# ...

# %%
grouped.agg?
# Out:
# Signature: grouped.agg(arg, *args, **kwargs)
# Docstring:
# Aggregate using one or more operations over the specified axis.
#
#
#
# Parameters
# ----------
# func : function, string, dictionary, or list of string/functions
#     Function to use for aggregating the data. If a function, must either
#     work when passed a DataFrame or when passed to DataFrame.apply. For
#     a DataFrame, can pass a dict, if the keys are DataFrame column names.
#
#     Accepted combinations are:
#
#     - string function name.
#     - function.
#     - list of functions.
#     - dict of column names -> functions (or list of functions).
#
#
# *args
#     Positional arguments to pass to `func`.
# **kwargs
#     Keyword arguments to pass to `func`.
#
# Returns
# -------
# aggregated : DataFrame
#
# Notes
# -----
# `agg` is an alias for `aggregate`. Use the alias.
#
# A passed user-defined-function will be passed a Series for evaluation.
#
# Examples
# --------
#
# ...

# %%
grouped['percent correct'].rank()
# Out:
# 0      10.0
# 1       5.0
# 2      18.0
# 3      15.5
# 4       3.5
# 5       2.0
# 6       3.0
# 7       1.0
# 8      17.0
# 9      11.0
# 10      3.5
# 11     19.0
# 12     13.0
# 13     13.0
# 14      5.0
# 15      7.5
# 16      7.5
# 17     13.0
# 18      4.0
# 19      2.0
# 20      7.5
# 21      6.0
# 22     15.5
# 23      1.0
# 24      7.5
# 25      1.0
# 26     27.5
# 27     13.0
# 28      7.0
# 29     49.5
#        ...
# 72     36.5
# 73     51.0
# 74     46.5
# 75     53.0
# 76      2.5
# 77     49.5
# 78     17.0
# 79     17.0
# 80     22.0
# 81      1.0
# 82     36.5
# 83     27.5
# 84     15.5
# 85     17.0
# 86      4.5
# 87     10.5
# 88     27.5
# 89     46.5
# 90     13.0
# 91      4.5
# 92     18.0
# 93     18.0
# 94      1.0
# 95     15.5
# 96      2.5
# 97     17.0
# 98     36.5
# 99     13.0
# 100     8.5
# 101     4.5
# Name: percent correct, Length: 102, dtype: float64

# %%
df['rank grouped by insomnia']= (grouped['percent correct'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-8bdd5ba7ec60> in <module>()
# ----> 1 df['rank grouped by insomnia']= (grouped['percent correct'])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3386
#    3387             # turn me into an ndarray
# ...

# %%
df_sorted=df.sort_values(by=['insomnia','percent correct'],
                        ascending=False)
df_sorted[['insomnia','percent correct','']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-b8ef09cb9551> in <module>()
#       1 df_sorted=df.sort_values(by=['insomnia','percent correct'],
#       2                         ascending=False)
# ----> 3 df_sorted[['insomnia','percent correct','']]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# ...
